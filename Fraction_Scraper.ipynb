# %%
import requests
from bs4 import BeautifulSoup

# %%
url = "https://www.sec.gov/divisions/enforce/friactions"  # Replace with the URL of the web page
response = requests.get(url)
html_content = response.content

# %%
soup = BeautifulSoup(html_content, 'html.parser')

# %%
soup
# Out:
# <!DOCTYPE html>
#
# <html dir="ltr" lang="en">
# <head>
# ...

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# Fetch the HTML content
url = "https://www.sec.gov/divisions/enforce/friactions"
response = requests.get(url)
html_content = response.content

# Parse the HTML content
soup = BeautifulSoup(html_content, 'html.parser')

# Find the table element
table = soup.find('table', class_='list')

# Extract table data and store it in a list of dictionaries
data = []
for row in table.find_all('tr', class_='pr-list-page-row'):
    date = row.find('time', class_='datetime').text.strip()
    respondents = row.find('div', class_='release-view__respondents').text.strip()
    
    release_numbers_element = row.find('div', class_='view-table_subfield view-table_subfield_release_number')
    release_numbers = release_numbers_element.text.strip() if release_numbers_element else None
    
    data.append({'Date': date, 'Respondents': respondents, 'Release Numbers': release_numbers})

# Create a DataFrame from the scraped data
df = pd.DataFrame(data)

# Print the DataFrame
df
# Out:
#             Date                                        Respondents  \
# 0   June 2, 2023  Pending Administrative Proceedings (Order Vaca...
# 1   June 2, 2023  Pending Administrative Proceedings (Order Dism...
# 2   June 1, 2023                              Carl S. Schwartz, CPA
# 3   May 26, 2023                                      Gartner, Inc.
# 4   May 25, 2023  Jia Roger Qian Wang, CPA and Wang Certified Pu...
# ..           ...                                                ...
# 95  Aug. 3, 2022                                 Brian K. Hutchison
# 96  Aug. 3, 2022    Surgalign Holdings, Inc. and Robert P. Jordheim
# 97  Aug. 3, 2022  Anton & Chia, LLP Wahl, Gregory A., CPA Deutch...
# 98  July 8, 2022                      Arcangelo Loberto, CPA and CA
# 99  July 8, 2022                           Steven J. Sheinfeld, CPA
#
#                                       Release Numbers
# 0   Release No.\n33-11199, 34-97641, IA-6324, IC-3...
# ...

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# Fetch the HTML content
url = "https://www.sec.gov/divisions/enforce/friactions"
response = requests.get(url)
html_content = response.content

# Parse the HTML content
soup = BeautifulSoup(html_content, 'html.parser')

# Find the table element
table = soup.find('table', class_='list')

# Extract table data and store it in a list of dictionaries
data = []
for row in table.find_all('tr', class_='pr-list-page-row'):
    date = row.find('time', class_='datetime').text.strip()
    
    respondents_element = row.find('div', class_='release-view__respondents')
    respondents = respondents_element.text.strip() if respondents_element else None
    
    release_numbers_element = row.find('div', class_='view-table_subfield view-table_subfield_release_number')
    release_numbers = release_numbers_element.text.strip() if release_numbers_element else None
    
    link_element = respondents_element.find('a')
    link = link_element['href'] if link_element else None
    
    data.append({'Date': date, 'Respondents': respondents, 'Release Numbers': release_numbers, 'Link': link})

# Create a DataFrame from the scraped data
df = pd.DataFrame(data)

# Print the DataFrame
df
# Out:
#             Date                                        Respondents  \
# 0   June 2, 2023  Pending Administrative Proceedings (Order Vaca...
# 1   June 2, 2023  Pending Administrative Proceedings (Order Dism...
# 2   June 1, 2023                              Carl S. Schwartz, CPA
# 3   May 26, 2023                                      Gartner, Inc.
# 4   May 25, 2023  Jia Roger Qian Wang, CPA and Wang Certified Pu...
# ..           ...                                                ...
# 95  Aug. 3, 2022                                 Brian K. Hutchison
# 96  Aug. 3, 2022    Surgalign Holdings, Inc. and Robert P. Jordheim
# 97  Aug. 3, 2022  Anton & Chia, LLP Wahl, Gregory A., CPA Deutch...
# 98  July 8, 2022                      Arcangelo Loberto, CPA and CA
# 99  July 8, 2022                           Steven J. Sheinfeld, CPA
#
#                                       Release Numbers  \
# 0   Release No.\n33-11199, 34-97641, IA-6324, IC-3...
# ...

# %%
df['Release Numbers'].iloc[0]
# Out:
# 'Release No.\n33-11199, 34-97641, IA-6324, IC-34934, AAER-4414'
